# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import u_net as unet
import skimage.io
import keras.backend as K
from keras.preprocessing.image import ImageDataGenerator
# Out:
# c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

# Keras related
from keras.callbacks import EarlyStopping, ModelCheckpoint
import tensorflow as tf

# %%
# Progress bar
from tqdm import tqdm

# %%
import random
import warnings
# Set some parameters
IMG_WIDTH = 128*2
IMG_HEIGHT = 128*2
IMG_CHANNELS = 3
TRAIN_PATH = 'data/'
TEST_PATH = ''

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
seed = 42
random.seed = seed
np.random.seed = seed

# %%
import os
# Get train and test IDs
train_ids = next(os.walk(TRAIN_PATH))[1]
# test_ids = next(os.walk(TEST_PATH))[1]

# %%
import sys
# Get and resize train images and masks
X_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
print('Getting and resizing train images and masks ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    path = TRAIN_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_train[n] = img
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
    for mask_file in next(os.walk(path + '/masks/'))[2]:
        mask_ = imread(path + '/masks/' + mask_file)
        mask_ = np.expand_dims(resize(mask_, (IMG_HEIGHT, IMG_WIDTH), mode='constant', 
                                      preserve_range=True), axis=-1)
        mask = np.maximum(mask, mask_)
    Y_train[n] = mask

# # Get and resize test images
# X_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
# sizes_test = []
# print('Getting and resizing test images ... ')
# sys.stdout.flush()
# for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):
#     path = TEST_PATH + id_
#     img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
#     sizes_test.append([img.shape[0], img.shape[1]])
#     img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
#     X_test[n] = img

print('Done!')
# Out:
# Getting and resizing train images and masks ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 670/670 [02:13<00:00,  5.04it/s]
# Done!

# %%
# Check if training data looks all right
ix = random.randint(0, len(train_ids))
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()
# Out:
# c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
import keras
import numpy as np 
import keras.backend as K
from keras.models import Model
from keras.layers import Input, Activation, Add, Concatenate, Dense
from keras.layers import Conv2D, MaxPooling2D, Dropout, UpSampling2D

""" Work with shitty network due to bad axis concatenation (not 0!)
    In UNet
"""

# model = unet.u_net(1, start=8, act="relu")

inputs = Input(shape=(256, 256, 3))
# Fourth/last block
fourth = MaxPooling2D()(inputs)
fourth = Conv2D(32, (3,3), padding="same")(fourth)
fourth = Activation(act)(fourth)
fourth = MaxPooling2D()(fourth)
fourth = Conv2D(64, (3,3), padding="same")(fourth)
fourth  = Activation(act)(fourth)

# STOP DOWNSAMPLING - START UPSAMPLING
# Reverse third - Upsampling conv (up-conv 2x2) as described in
# the original paper
r_third = UpSampling2D()(fourth)
r_third = Conv2D(64, (2,2), padding="same")(r_third)
r_third = Activation(act)(r_third)
r_third = UpSampling2D()(r_third)
r_third = Conv2D(32, (2,2), padding="same")(r_third)
r_third = Activation(act)(r_third)
# Normal part
r_first = Conv2D(1, (1,1), padding="same")(r_third)
outputs = Activation("sigmoid")(r_first)
model = Model(inputs=inputs, outputs=outputs)


loss = unet.IoU
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 256, 256, 3)       0
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 128, 128, 3)       0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 128, 128, 32)      896
# _________________________________________________________________
# activation_23 (Activation)   (None, 128, 128, 32)      0
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 64, 64, 64)        18496
# _________________________________________________________________
# activation_24 (Activation)   (None, 64, 64, 64)        0
# _________________________________________________________________
# up_sampling2d_6 (UpSampling2 (None, 128, 128, 64)      0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 128, 128, 64)      16448
# _________________________________________________________________
# activation_25 (Activation)   (None, 128, 128, 64)      0
# _________________________________________________________________
# up_sampling2d_7 (UpSampling2 (None, 256, 256, 64)      0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 256, 256, 32)      8224
# _________________________________________________________________
# activation_26 (Activation)   (None, 256, 256, 32)      0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 256, 256, 1)       33
# _________________________________________________________________
# activation_27 (Activation)   (None, 256, 256, 1)       0
# =================================================================
# Total params: 44,097
# Trainable params: 44,097
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Define IoU metric
def mean_iou(y_true, y_pred):
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)

# %%
def fuck_loss(y_true, y_pred):
    print(K.int_shape(y_true))
    print(K.int_shape(y_pred))
    return K.mean(K.square(y_pred - y_true), axis=-1)

# %%
# #data augmentation
# datagen = ImageDataGenerator()
# datagen.fit(X_train)

# %%
# Rescale the data
# X_train /= 255
# Compile the model
model.compile(optimizer='adam', loss=fuck_loss, metrics=[mean_iou]) # mean_iou
# Out:
# (None, None, None, None)
# (None, 256, 256, 1)

# %%
print(X_train.shape)
# Out:
# (670, 256, 256, 3)

# %%
print(Y_train.shape)
# Out:
# (670, 256, 256, 1)

# %%
# Ensure model works
preds = model.predict(X_train)

# %%
# Fit model
earlystopper = EarlyStopping(patience=5, verbose=1)
checkpointer = ModelCheckpoint('model-dsbowl2018-1.h5', verbose=1, save_best_only=True)
results = model.fit(X_train, Y_train, validation_split=0.1, batch_size=32, epochs=20, verbose=1) # callbacks=[earlystopper, checkpointer],
# Out:
# Train on 603 samples, validate on 67 samples
# Epoch 1/20
# 603/603 [==============================] - ETA: 19s - loss: 0.2041 - mean_iou: 0.0000e+0 - ETA: 14s - loss: 0.1835 - mean_iou: 0.2418    - ETA: 12s - loss: 0.1867 - mean_iou: 0.315 - ETA: 10s - loss: 0.1742 - mean_iou: 0.347 - ETA: 9s - loss: 0.1658 - mean_iou: 0.366 - ETA: 8s - loss: 0.1588 - mean_iou: 0.37 - ETA: 7s - loss: 0.1577 - mean_iou: 0.38 - ETA: 6s - loss: 0.1614 - mean_iou: 0.39 - ETA: 6s - loss: 0.1597 - mean_iou: 0.39 - ETA: 5s - loss: 0.1614 - mean_iou: 0.40 - ETA: 4s - loss: 0.1576 - mean_iou: 0.40 - ETA: 4s - loss: 0.1587 - mean_iou: 0.40 - ETA: 3s - loss: 0.1587 - mean_iou: 0.40 - ETA: 2s - loss: 0.1578 - mean_iou: 0.41 - ETA: 2s - loss: 0.1564 - mean_iou: 0.41 - ETA: 1s - loss: 0.1573 - mean_iou: 0.41 - ETA: 1s - loss: 0.1577 - mean_iou: 0.41 - ETA: 0s - loss: 0.1574 - mean_iou: 0.41 - 11s 19ms/step - loss: 0.1572 - mean_iou: 0.4157 - val_loss: 0.1433 - val_mean_iou: 0.4282
# Epoch 2/20
# 603/603 [==============================] - ETA: 9s - loss: 0.1872 - mean_iou: 0.42 - ETA: 8s - loss: 0.1713 - mean_iou: 0.42 - ETA: 8s - loss: 0.1686 - mean_iou: 0.42 - ETA: 7s - loss: 0.1652 - mean_iou: 0.42 - ETA: 7s - loss: 0.1608 - mean_iou: 0.42 - ETA: 6s - loss: 0.1584 - mean_iou: 0.42 - ETA: 6s - loss: 0.1583 - mean_iou: 0.42 - ETA: 5s - loss: 0.1563 - mean_iou: 0.42 - ETA: 5s - loss: 0.1541 - mean_iou: 0.42 - ETA: 4s - loss: 0.1521 - mean_iou: 0.42 - ETA: 4s - loss: 0.1531 - mean_iou: 0.42 - ETA: 3s - loss: 0.1521 - mean_iou: 0.42 - ETA: 3s - loss: 0.1524 - mean_iou: 0.42 - ETA: 2s - loss: 0.1516 - mean_iou: 0.42 - ETA: 2s - loss: 0.1501 - mean_iou: 0.42 - ETA: 1s - loss: 0.1501 - mean_iou: 0.42 - ETA: 0s - loss: 0.1508 - mean_iou: 0.42 - ETA: 0s - loss: 0.1523 - mean_iou: 0.42 - 11s 17ms/step - loss: 0.1526 - mean_iou: 0.4271 - val_loss: 0.1412 - val_mean_iou: 0.4263
# Epoch 3/20
# 603/603 [==============================] - ETA: 9s - loss: 0.1632 - mean_iou: 0.42 - ETA: 8s - loss: 0.1394 - mean_iou: 0.42 - ETA: 8s - loss: 0.1448 - mean_iou: 0.42 - ETA: 8s - loss: 0.1522 - mean_iou: 0.42 - ETA: 7s - loss: 0.1574 - mean_iou: 0.42 - ETA: 6s - loss: 0.1557 - mean_iou: 0.42 - ETA: 6s - loss: 0.1554 - mean_iou: 0.42 - ETA: 5s - loss: 0.1574 - mean_iou: 0.42 - ETA: 5s - loss: 0.1567 - mean_iou: 0.42 - ETA: 4s - loss: 0.1551 - mean_iou: 0.42 - ETA: 4s - loss: 0.1553 - mean_iou: 0.42 - ETA: 3s - loss: 0.1557 - mean_iou: 0.42 - ETA: 3s - loss: 0.1564 - mean_iou: 0.42 - ETA: 2s - loss: 0.1566 - mean_iou: 0.42 - ETA: 2s - loss: 0.1539 - mean_iou: 0.42 - ETA: 1s - loss: 0.1532 - mean_iou: 0.42 - ETA: 0s - loss: 0.1523 - mean_iou: 0.42 - ETA: 0s - loss: 0.1510 - mean_iou: 0.42 - 11s 18ms/step - loss: 0.1522 - mean_iou: 0.4259 - val_loss: 0.1403 - val_mean_iou: 0.4257
# Epoch 4/20
# 603/603 [==============================] - ETA: 9s - loss: 0.1561 - mean_iou: 0.42 - ETA: 9s - loss: 0.1426 - mean_iou: 0.42 - ETA: 8s - loss: 0.1430 - mean_iou: 0.42 - ETA: 8s - loss: 0.1390 - mean_iou: 0.42 - ETA: 7s - loss: 0.1389 - mean_iou: 0.42 - ETA: 6s - loss: 0.1399 - mean_iou: 0.42 - ETA: 6s - loss: 0.1455 - mean_iou: 0.42 - ETA: 5s - loss: 0.1434 - mean_iou: 0.42 - ETA: 5s - loss: 0.1474 - mean_iou: 0.42 - ETA: 4s - loss: 0.1489 - mean_iou: 0.42 - ETA: 4s - loss: 0.1487 - mean_iou: 0.42 - ETA: 3s - loss: 0.1485 - mean_iou: 0.42 - ETA: 3s - loss: 0.1480 - mean_iou: 0.42 - ETA: 2s - loss: 0.1455 - mean_iou: 0.42 - ETA: 2s - loss: 0.1467 - mean_iou: 0.42 - ETA: 1s - loss: 0.1498 - mean_iou: 0.42 - ETA: 0s - loss: 0.1505 - mean_iou: 0.42 - ETA: 0s - loss: 0.1514 - mean_iou: 0.42 - 11s 18ms/step - loss: 0.1522 - mean_iou: 0.4259 - val_loss: 0.1402 - val_mean_iou: 0.4254
# Epoch 5/20
# 603/603 [==============================] - ETA: 9s - loss: 0.1505 - mean_iou: 0.42 - ETA: 8s - loss: 0.1579 - mean_iou: 0.42 - ETA: 8s - loss: 0.1602 - mean_iou: 0.42 - ETA: 7s - loss: 0.1496 - mean_iou: 0.42 - ETA: 7s - loss: 0.1502 - mean_iou: 0.42 - ETA: 6s - loss: 0.1593 - mean_iou: 0.42 - ETA: 6s - loss: 0.1612 - mean_iou: 0.42 - ETA: 5s - loss: 0.1599 - mean_iou: 0.42 - ETA: 5s - loss: 0.1595 - mean_iou: 0.42 - ETA: 4s - loss: 0.1580 - mean_iou: 0.42 - ETA: 4s - loss: 0.1559 - mean_iou: 0.42 - ETA: 3s - loss: 0.1555 - mean_iou: 0.42 - ETA: 3s - loss: 0.1546 - mean_iou: 0.42 - ETA: 2s - loss: 0.1531 - mean_iou: 0.42 - ETA: 2s - loss: 0.1521 - mean_iou: 0.42 - ETA: 1s - loss: 0.1518 - mean_iou: 0.42 - ETA: 0s - loss: 0.1519 - mean_iou: 0.42 - ETA: 0s - loss: 0.1504 - mean_iou: 0.42 - 10s 17ms/step - loss: 0.1522 - mean_iou: 0.4253 - val_loss: 0.1402 - val_mean_iou: 0.4252
# Epoch 6/20
# 603/603 [==============================] - ETA: 8s - loss: 0.1572 - mean_iou: 0.42 - ETA: 8s - loss: 0.1608 - mean_iou: 0.42 - ETA: 8s - loss: 0.1509 - mean_iou: 0.42 - ETA: 7s - loss: 0.1421 - mean_iou: 0.42 - ETA: 7s - loss: 0.1464 - mean_iou: 0.42 - ETA: 6s - loss: 0.1516 - mean_iou: 0.42 - ETA: 6s - loss: 0.1505 - mean_iou: 0.42 - ETA: 5s - loss: 0.1506 - mean_iou: 0.42 - ETA: 5s - loss: 0.1525 - mean_iou: 0.42 - ETA: 4s - loss: 0.1546 - mean_iou: 0.42 - ETA: 4s - loss: 0.1562 - mean_iou: 0.42 - ETA: 3s - loss: 0.1573 - mean_iou: 0.42 - ETA: 3s - loss: 0.1575 - mean_iou: 0.42 - ETA: 2s - loss: 0.1582 - mean_iou: 0.42 - ETA: 2s - loss: 0.1556 - mean_iou: 0.42 - ETA: 1s - loss: 0.1544 - mean_iou: 0.42 - ETA: 0s - loss: 0.1531 - mean_iou: 0.42 - ETA: 0s - loss: 0.1530 - mean_iou: 0.42 - 10s 17ms/step - loss: 0.1522 - mean_iou: 0.4252 - val_loss: 0.1402 - val_mean_iou: 0.4251
# Epoch 7/20
# 603/603 [==============================] - ETA: 9s - loss: 0.1432 - mean_iou: 0.42 - ETA: 8s - loss: 0.1427 - mean_iou: 0.42 - ETA: 8s - loss: 0.1448 - mean_iou: 0.42 - ETA: 7s - loss: 0.1520 - mean_iou: 0.42 - ETA: 7s - loss: 0.1502 - mean_iou: 0.42 - ETA: 6s - loss: 0.1560 - mean_iou: 0.42 - ETA: 6s - loss: 0.1571 - mean_iou: 0.42 - ETA: 5s - loss: 0.1500 - mean_iou: 0.42 - ETA: 5s - loss: 0.1468 - mean_iou: 0.42 - ETA: 4s - loss: 0.1456 - mean_iou: 0.42 - ETA: 4s - loss: 0.1476 - mean_iou: 0.42 - ETA: 3s - loss: 0.1520 - mean_iou: 0.42 - ETA: 3s - loss: 0.1526 - mean_iou: 0.42 - ETA: 2s - loss: 0.1501 - mean_iou: 0.42 - ETA: 2s - loss: 0.1505 - mean_iou: 0.42 - ETA: 1s - loss: 0.1499 - mean_iou: 0.42 - ETA: 0s - loss: 0.1517 - mean_iou: 0.42 - ETA: 0s - loss: 0.1511 - mean_iou: 0.42 - 10s 17ms/step - loss: 0.1522 - mean_iou: 0.4252 - val_loss: 0.1402 - val_mean_iou: 0.4250
# Epoch 8/20
# 603/603 [==============================] - ETA: 9s - loss: 0.1667 - mean_iou: 0.42 - ETA: 8s - loss: 0.1668 - mean_iou: 0.42 - ETA: 8s - loss: 0.1610 - mean_iou: 0.42 - ETA: 7s - loss: 0.1590 - mean_iou: 0.42 - ETA: 7s - loss: 0.1584 - mean_iou: 0.42 - ETA: 6s - loss: 0.1587 - mean_iou: 0.42 - ETA: 6s - loss: 0.1518 - mean_iou: 0.42 - ETA: 5s - loss: 0.1538 - mean_iou: 0.42 - ETA: 5s - loss: 0.1559 - mean_iou: 0.42 - ETA: 4s - loss: 0.1555 - mean_iou: 0.42 - ETA: 4s - loss: 0.1545 - mean_iou: 0.42 - ETA: 3s - loss: 0.1549 - mean_iou: 0.42 - ETA: 3s - loss: 0.1532 - mean_iou: 0.42 - ETA: 2s - loss: 0.1523 - mean_iou: 0.42 - ETA: 2s - loss: 0.1537 - mean_iou: 0.42 - ETA: 1s - loss: 0.1535 - mean_iou: 0.42 - ETA: 0s - loss: 0.1518 - mean_iou: 0.42 - ETA: 0s - loss: 0.1523 - mean_iou: 0.42 - 11s 17ms/step - loss: 0.1522 - mean_iou: 0.4250 - val_loss: 0.1402 - val_mean_iou: 0.4250
# Epoch 9/20
# 603/603 [==============================] - ETA: 9s - loss: 0.1399 - mean_iou: 0.42 - ETA: 8s - loss: 0.1527 - mean_iou: 0.42 - ETA: 8s - loss: 0.1468 - mean_iou: 0.42 - ETA: 7s - loss: 0.1415 - mean_iou: 0.42 - ETA: 7s - loss: 0.1463 - mean_iou: 0.42 - ETA: 6s - loss: 0.1473 - mean_iou: 0.42 - ETA: 6s - loss: 0.1478 - mean_iou: 0.42 - ETA: 5s - loss: 0.1519 - mean_iou: 0.42 - ETA: 5s - loss: 0.1543 - mean_iou: 0.42 - ETA: 4s - loss: 0.1548 - mean_iou: 0.42 - ETA: 4s - loss: 0.1515 - mean_iou: 0.42 - ETA: 3s - loss: 0.1511 - mean_iou: 0.42 - ETA: 3s - loss: 0.1538 - mean_iou: 0.42 - ETA: 2s - loss: 0.1533 - mean_iou: 0.42 - ETA: 2s - loss: 0.1523 - mean_iou: 0.42 - ETA: 1s - loss: 0.1524 - mean_iou: 0.42 - ETA: 0s - loss: 0.1525 - mean_iou: 0.42 - ETA: 0s - loss: 0.1521 - mean_iou: 0.42 - 11s 18ms/step - loss: 0.1522 - mean_iou: 0.4250 - val_loss: 0.1402 - val_mean_iou: 0.4249
# Epoch 10/20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-f43c2a3b2011> in <module>()
#       2 earlystopper = EarlyStopping(patience=5, verbose=1)
#       3 checkpointer = ModelCheckpoint('model-dsbowl2018-1.h5', verbose=1, save_best_only=True)
# ----> 4 results = model.fit(X_train, Y_train, validation_split=0.1, batch_size=32, epochs=20, verbose=1) # callbacks=[earlystopper, checkpointer],
#
# c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1655                               initial_epoch=initial_epoch,
#    1656                               steps_per_epoch=steps_per_epoch,
# -> 1657                               validation_steps=validation_steps)
#    1658
#    1659     def evaluate(self, x=None, y=None,
#
# c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\keras\engine\training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1211                     batch_logs['size'] = len(batch_ids)
#    1212                     callbacks.on_batch_begin(batch_index, batch_logs)
# -> 1213                     outs = f(ins_batch)
#    1214                     if not isinstance(outs, list):
#    1215                         outs = [outs]
#
# c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2355         session = get_session()
#    2356         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2357                               **self.session_kwargs)
#    2358         return updated[:len(self.outputs)]
#    2359
#
# c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# Predict on train set
preds_train = model.predict(X_train[:int(X_train.shape[0]*0.9)], verbose=1)
# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.uint8)
# Out:
# 603/603 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 2s 4ms/step

# %%
# Perform a sanity check on some random training samples
ix = random.randint(0, len(preds_train_t))
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()
imshow(np.squeeze(preds_train_t[ix]))
plt.show()
# Out:
# c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
